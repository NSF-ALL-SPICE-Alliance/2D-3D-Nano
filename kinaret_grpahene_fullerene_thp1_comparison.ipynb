# %% [markdown]
# ## Kinaret 2D vs 3D Carbon Nanomaterials Analysis

# %%
"""
OBJECTIVE 1: Compare 2D vs 3D Carbon Nanomaterials in THP-1 Cells
Kinaret GSE92901 Dataset

This notebook compares:
- 2D Graphene (SES) vs Control
- 3D Fullerene vs Control
- Direct comparison of 2D vs 3D effects

All in the SAME cell type (THP-1 macrophages)
"""

# Install required packages (run once)
# !pip install gseapy GEOparse matplotlib seaborn scipy matplotlib-venn -q

# Import libraries
import pandas as pd
import numpy as np
import gseapy as gp
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import GEOparse
import warnings
warnings.filterwarnings('ignore')

print("✅ All packages imported successfully!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.3/601.3 kB 16.8 MB/s eta 0:00:00
# ✅ All packages imported successfully!

# %% [markdown]
# Cell 2: Load Kinaret Data

# %%
print("="*60)
print("LOADING KINARET GSE92901 DATA")
print("="*60)

# Download data from GEO
gse = GEOparse.get_GEO("GSE92901", destdir="./geo_data")
gpl = GEOparse.get_GEO(geo="GPL10332", destdir="./geo_data")

print(f"✅ Loaded GSE92901: {len(gse.gsms)} samples")
# Out:
# 12-Nov-2025 19:34:31 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE92nnn/GSE92901/soft/GSE92901_family.soft.gz to ./geo_data/GSE92901_family.soft.gz
# INFO:GEOparse:Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE92nnn/GSE92901/soft/GSE92901_family.soft.gz to ./geo_data/GSE92901_family.soft.gz
# ============================================================
# LOADING KINARET GSE92901 DATA
# ============================================================
# 100%|██████████| 37.5M/37.5M [00:12<00:00, 3.13MB/s]
# 12-Nov-2025 19:34:44 DEBUG downloader - Size validation passed
# DEBUG:GEOparse:Size validation passed
# 12-Nov-2025 19:34:44 DEBUG downloader - Moving /tmp/tmp096tmofe to /content/geo_data/GSE92901_family.soft.gz
# DEBUG:GEOparse:Moving /tmp/tmp096tmofe to /content/geo_data/GSE92901_family.soft.gz
# 12-Nov-2025 19:34:44 DEBUG downloader - Successfully downloaded ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE92nnn/GSE92901/soft/GSE92901_family.soft.gz
# DEBUG:GEOparse:Successfully downloaded ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE92nnn/GSE92901/soft/GSE92901_family.soft.gz
# 12-Nov-2025 19:34:44 INFO GEOparse - Parsing ./geo_data/GSE92901_family.soft.gz:
# INFO:GEOparse:Parsing ./geo_data/GSE92901_family.soft.gz:
# 12-Nov-2025 19:34:44 DEBUG GEOparse - DATABASE: GeoMiame
# DEBUG:GEOparse:DATABASE: GeoMiame
# 12-Nov-2025 19:34:44 DEBUG GEOparse - SERIES: GSE92901
# DEBUG:GEOparse:SERIES: GSE92901
# 12-Nov-2025 19:34:44 DEBUG GEOparse - PLATFORM: GPL10332
# DEBUG:GEOparse:PLATFORM: GPL10332
# 12-Nov-2025 19:34:45 DEBUG GEOparse - PLATFORM: GPL13912
# DEBUG:GEOparse:PLATFORM: GPL13912
# 12-Nov-2025 19:34:46 DEBUG GEOparse - SAMPLE: GSM2439561
# DEBUG:GEOparse:SAMPLE: GSM2439561
# 12-Nov-2025 19:34:46 DEBUG GEOparse - SAMPLE: GSM2439562
# DEBUG:GEOparse:SAMPLE: GSM2439562
# 12-Nov-2025 19:34:46 DEBUG GEOparse - SAMPLE: GSM2439563
# DEBUG:GEOparse:SAMPLE: GSM2439563
# 12-Nov-2025 19:34:46 DEBUG GEOparse - SAMPLE: GSM2439564
# DEBUG:GEOparse:SAMPLE: GSM2439564
# 12-Nov-2025 19:34:47 DEBUG GEOparse - SAMPLE: GSM2439565
# DEBUG:GEOparse:SAMPLE: GSM2439565
# 12-Nov-2025 19:34:47 DEBUG GEOparse - SAMPLE: GSM2439566
# DEBUG:GEOparse:SAMPLE: GSM2439566
# 12-Nov-2025 19:34:47 DEBUG GEOparse - SAMPLE: GSM2439567
# DEBUG:GEOparse:SAMPLE: GSM2439567
# 12-Nov-2025 19:34:47 DEBUG GEOparse - SAMPLE: GSM2439568
# DEBUG:GEOparse:SAMPLE: GSM2439568
# 12-Nov-2025 19:34:47 DEBUG GEOparse - SAMPLE: GSM2439569
# DEBUG:GEOparse:SAMPLE: GSM2439569
# 12-Nov-2025 19:34:47 DEBUG GEOparse - SAMPLE: GSM2439570
# DEBUG:GEOparse:SAMPLE: GSM2439570
# 12-Nov-2025 19:34:47 DEBUG GEOparse - SAMPLE: GSM2439571
# DEBUG:GEOparse:SAMPLE: GSM2439571
# 12-Nov-2025 19:34:47 DEBUG GEOparse - SAMPLE: GSM2439572
# DEBUG:GEOparse:SAMPLE: GSM2439572
# 12-Nov-2025 19:34:47 DEBUG GEOparse - SAMPLE: GSM2439573
# DEBUG:GEOparse:SAMPLE: GSM2439573
# 12-Nov-2025 19:34:47 DEBUG GEOparse - SAMPLE: GSM2439574
# DEBUG:GEOparse:SAMPLE: GSM2439574
# 12-Nov-2025 19:34:47 DEBUG GEOparse - SAMPLE: GSM2439575
# DEBUG:GEOparse:SAMPLE: GSM2439575
# 12-Nov-2025 19:34:47 DEBUG GEOparse - SAMPLE: GSM2439576
# DEBUG:GEOparse:SAMPLE: GSM2439576
# 12-Nov-2025 19:34:47 DEBUG GEOparse - SAMPLE: GSM2439577
# DEBUG:GEOparse:SAMPLE: GSM2439577
# 12-Nov-2025 19:34:47 DEBUG GEOparse - SAMPLE: GSM2439578
# DEBUG:GEOparse:SAMPLE: GSM2439578
# 12-Nov-2025 19:34:47 DEBUG GEOparse - SAMPLE: GSM2439579
# DEBUG:GEOparse:SAMPLE: GSM2439579
# 12-Nov-2025 19:34:48 DEBUG GEOparse - SAMPLE: GSM2439580
# DEBUG:GEOparse:SAMPLE: GSM2439580
# 12-Nov-2025 19:34:48 DEBUG GEOparse - SAMPLE: GSM2439581
# DEBUG:GEOparse:SAMPLE: GSM2439581
# 12-Nov-2025 19:34:48 DEBUG GEOparse - SAMPLE: GSM2439582
# DEBUG:GEOparse:SAMPLE: GSM2439582
# 12-Nov-2025 19:34:48 DEBUG GEOparse - SAMPLE: GSM2439583
# DEBUG:GEOparse:SAMPLE: GSM2439583
# 12-Nov-2025 19:34:48 DEBUG GEOparse - SAMPLE: GSM2439584
# DEBUG:GEOparse:SAMPLE: GSM2439584
# 12-Nov-2025 19:34:48 DEBUG GEOparse - SAMPLE: GSM2439585
# DEBUG:GEOparse:SAMPLE: GSM2439585
# 12-Nov-2025 19:34:48 DEBUG GEOparse - SAMPLE: GSM2439586
# DEBUG:GEOparse:SAMPLE: GSM2439586
# 12-Nov-2025 19:34:48 DEBUG GEOparse - SAMPLE: GSM2439587
# DEBUG:GEOparse:SAMPLE: GSM2439587
# 12-Nov-2025 19:34:48 DEBUG GEOparse - SAMPLE: GSM2439588
# DEBUG:GEOparse:SAMPLE: GSM2439588
# 12-Nov-2025 19:34:48 DEBUG GEOparse - SAMPLE: GSM2439589
# DEBUG:GEOparse:SAMPLE: GSM2439589
# 12-Nov-2025 19:34:48 DEBUG GEOparse - SAMPLE: GSM2439590
# DEBUG:GEOparse:SAMPLE: GSM2439590
# 12-Nov-2025 19:34:48 DEBUG GEOparse - SAMPLE: GSM2439591
# DEBUG:GEOparse:SAMPLE: GSM2439591
# 12-Nov-2025 19:34:48 DEBUG GEOparse - SAMPLE: GSM2439592
# DEBUG:GEOparse:SAMPLE: GSM2439592
# 12-Nov-2025 19:34:48 DEBUG GEOparse - SAMPLE: GSM2439593
# DEBUG:GEOparse:SAMPLE: GSM2439593
# 12-Nov-2025 19:34:49 DEBUG GEOparse - SAMPLE: GSM2439594
# DEBUG:GEOparse:SAMPLE: GSM2439594
# 12-Nov-2025 19:34:49 DEBUG GEOparse - SAMPLE: GSM2439595
# DEBUG:GEOparse:SAMPLE: GSM2439595
# 12-Nov-2025 19:34:49 DEBUG GEOparse - SAMPLE: GSM2439596
# DEBUG:GEOparse:SAMPLE: GSM2439596
# 12-Nov-2025 19:34:49 DEBUG GEOparse - SAMPLE: GSM2439597
# DEBUG:GEOparse:SAMPLE: GSM2439597
# 12-Nov-2025 19:34:49 DEBUG GEOparse - SAMPLE: GSM2439598
# DEBUG:GEOparse:SAMPLE: GSM2439598
# 12-Nov-2025 19:34:49 DEBUG GEOparse - SAMPLE: GSM2439599
# DEBUG:GEOparse:SAMPLE: GSM2439599
# 12-Nov-2025 19:34:49 DEBUG GEOparse - SAMPLE: GSM2439600
# DEBUG:GEOparse:SAMPLE: GSM2439600
# 12-Nov-2025 19:34:49 DEBUG GEOparse - SAMPLE: GSM2439601
# DEBUG:GEOparse:SAMPLE: GSM2439601
# 12-Nov-2025 19:34:49 DEBUG GEOparse - SAMPLE: GSM2439602
# DEBUG:GEOparse:SAMPLE: GSM2439602
# 12-Nov-2025 19:34:49 DEBUG GEOparse - SAMPLE: GSM2439603
# DEBUG:GEOparse:SAMPLE: GSM2439603
# 12-Nov-2025 19:34:49 DEBUG GEOparse - SAMPLE: GSM2439604
# DEBUG:GEOparse:SAMPLE: GSM2439604
# 12-Nov-2025 19:34:49 DEBUG GEOparse - SAMPLE: GSM2439605
# DEBUG:GEOparse:SAMPLE: GSM2439605
# 12-Nov-2025 19:34:49 DEBUG GEOparse - SAMPLE: GSM2439606
# DEBUG:GEOparse:SAMPLE: GSM2439606
# 12-Nov-2025 19:34:49 DEBUG GEOparse - SAMPLE: GSM2439607
# DEBUG:GEOparse:SAMPLE: GSM2439607
# 12-Nov-2025 19:34:49 DEBUG GEOparse - SAMPLE: GSM2439608
# DEBUG:GEOparse:SAMPLE: GSM2439608
# 12-Nov-2025 19:34:50 DEBUG GEOparse - SAMPLE: GSM2439609
# DEBUG:GEOparse:SAMPLE: GSM2439609
# 12-Nov-2025 19:34:50 DEBUG GEOparse - SAMPLE: GSM2439610
# DEBUG:GEOparse:SAMPLE: GSM2439610
# 12-Nov-2025 19:34:50 DEBUG GEOparse - SAMPLE: GSM2439611
# DEBUG:GEOparse:SAMPLE: GSM2439611
# 12-Nov-2025 19:34:50 DEBUG GEOparse - SAMPLE: GSM2439612
# DEBUG:GEOparse:SAMPLE: GSM2439612
# 12-Nov-2025 19:34:50 DEBUG GEOparse - SAMPLE: GSM2439613
# DEBUG:GEOparse:SAMPLE: GSM2439613
# 12-Nov-2025 19:34:50 DEBUG GEOparse - SAMPLE: GSM2439614
# DEBUG:GEOparse:SAMPLE: GSM2439614
# 12-Nov-2025 19:34:50 DEBUG GEOparse - SAMPLE: GSM2439615
# DEBUG:GEOparse:SAMPLE: GSM2439615
# 12-Nov-2025 19:34:50 DEBUG GEOparse - SAMPLE: GSM2439616
# DEBUG:GEOparse:SAMPLE: GSM2439616
# 12-Nov-2025 19:34:50 DEBUG GEOparse - SAMPLE: GSM2439617
# DEBUG:GEOparse:SAMPLE: GSM2439617
# 12-Nov-2025 19:34:50 DEBUG GEOparse - SAMPLE: GSM2439618
# DEBUG:GEOparse:SAMPLE: GSM2439618
# 12-Nov-2025 19:34:51 DEBUG GEOparse - SAMPLE: GSM2439619
# DEBUG:GEOparse:SAMPLE: GSM2439619
# 12-Nov-2025 19:34:51 DEBUG GEOparse - SAMPLE: GSM2439620
# DEBUG:GEOparse:SAMPLE: GSM2439620
# 12-Nov-2025 19:34:51 DEBUG GEOparse - SAMPLE: GSM2439621
# DEBUG:GEOparse:SAMPLE: GSM2439621
# 12-Nov-2025 19:34:51 DEBUG GEOparse - SAMPLE: GSM2439622
# DEBUG:GEOparse:SAMPLE: GSM2439622
# 12-Nov-2025 19:34:51 DEBUG GEOparse - SAMPLE: GSM2439623
# DEBUG:GEOparse:SAMPLE: GSM2439623
# 12-Nov-2025 19:34:51 DEBUG GEOparse - SAMPLE: GSM2439624
# DEBUG:GEOparse:SAMPLE: GSM2439624
# 12-Nov-2025 19:34:51 DEBUG GEOparse - SAMPLE: GSM2439625
# DEBUG:GEOparse:SAMPLE: GSM2439625
# 12-Nov-2025 19:34:51 DEBUG GEOparse - SAMPLE: GSM2439626
# DEBUG:GEOparse:SAMPLE: GSM2439626
# 12-Nov-2025 19:34:51 DEBUG GEOparse - SAMPLE: GSM2439627
# DEBUG:GEOparse:SAMPLE: GSM2439627
# 12-Nov-2025 19:34:51 DEBUG GEOparse - SAMPLE: GSM2439628
# DEBUG:GEOparse:SAMPLE: GSM2439628
# 12-Nov-2025 19:34:52 DEBUG GEOparse - SAMPLE: GSM2439629
# DEBUG:GEOparse:SAMPLE: GSM2439629
# 12-Nov-2025 19:34:52 DEBUG GEOparse - SAMPLE: GSM2439630
# DEBUG:GEOparse:SAMPLE: GSM2439630
# 12-Nov-2025 19:34:52 DEBUG GEOparse - SAMPLE: GSM2439631
# DEBUG:GEOparse:SAMPLE: GSM2439631
# 12-Nov-2025 19:34:52 DEBUG GEOparse - SAMPLE: GSM2439632
# DEBUG:GEOparse:SAMPLE: GSM2439632
# 12-Nov-2025 19:34:52 DEBUG utils - Directory ./geo_data already exists. Skipping.
# DEBUG:GEOparse:Directory ./geo_data already exists. Skipping.
# 12-Nov-2025 19:34:52 INFO GEOparse - Downloading http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?targ=self&acc=GPL10332&form=text&view=full to ./geo_data/GPL10332.txt
# INFO:GEOparse:Downloading http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?targ=self&acc=GPL10332&form=text&view=full to ./geo_data/GPL10332.txt
# 12-Nov-2025 19:34:53 DEBUG downloader - Total size: 0
# DEBUG:GEOparse:Total size: 0
# 12-Nov-2025 19:34:53 DEBUG downloader - md5: None
# DEBUG:GEOparse:md5: None
# 25.8MB [00:01, 14.0MB/s]
# 12-Nov-2025 19:34:55 DEBUG downloader - Moving /tmp/tmp5hfcjewk to /content/geo_data/GPL10332.txt
# DEBUG:GEOparse:Moving /tmp/tmp5hfcjewk to /content/geo_data/GPL10332.txt
# 12-Nov-2025 19:34:55 DEBUG downloader - Successfully downloaded http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?targ=self&acc=GPL10332&form=text&view=full
# DEBUG:GEOparse:Successfully downloaded http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?targ=self&acc=GPL10332&form=text&view=full
# 12-Nov-2025 19:34:55 INFO GEOparse - Parsing ./geo_data/GPL10332.txt:
# INFO:GEOparse:Parsing ./geo_data/GPL10332.txt:
# 12-Nov-2025 19:34:55 DEBUG GEOparse - PLATFORM: GPL10332
# DEBUG:GEOparse:PLATFORM: GPL10332
# ✅ Loaded GSE92901: 72 samples

# %% [markdown]
# Cell 3: Extract Sample Metadata

# %%
# Extract sample metadata
sample_metadata = []
for gsm_name, gsm in gse.gsms.items():
    title = gsm.metadata.get("title", ["Unknown"])[0]
    parts = title.split(".")

    if len(parts) >= 3:
        treatment = parts[0]
        timepoint = parts[1]
        replicate = parts[2]
    else:
        treatment = title
        timepoint = "unknown"
        replicate = "1"

    sample_metadata.append({
        "GSM": gsm_name,
        "title": title,
        "treatment": treatment,
        "timepoint": timepoint,
        "replicate": replicate
    })

meta_df = pd.DataFrame(sample_metadata)

print("Available treatments:")
print(meta_df.groupby(['treatment', 'timepoint']).size())
# Out:
# Available treatments:
# treatment        timepoint
# 10_id_SES        unknown      1
# 11_id_SES        unknown      1
# 12_id_SES        unknown      1
# 13_id_Graphite   unknown      1
# 14_id_Graphite   unknown      1
# 15_id_Graphite   unknown      1
# 16_id_Graphite   unknown      1
# 17_id_BayTubes   unknown      1
# 18_id_BayTubes   unknown      1
# 19_id_BayTubes   unknown      1
# 1_id_Ctrl        unknown      1
# 20_id_BayTubes   unknown      1
# 21_id_fullerene  unknown      1
# 22_id_fullerene  unknown      1
# 23_id_fullerene  unknown      1
# 24_id_fullerene  unknown      1
# 2_id_Ctrl        unknown      1
# 3_id_Ctrl        unknown      1
# 4_id_rCNT        unknown      1
# 5_id_rCNT        unknown      1
# 6_id_rCNT        unknown      1
# 7_id_tCNT        unknown      1
# 8_id_tCNT        unknown      1
# 9_id_tCNT        unknown      1
# Baytube          24h          3
#                  6h           3
# Fullerene        24h          3
#                  6h           3
# Graphite         24h          3
#                  6h           3
# SES              24h          3
#                  6h           3
# negCont          24h          6
#                  6h           6
# rCNT             24h          3
#                  6h           3
# tCNT             24h          3
#                  6h           3
# dtype: int64

# %% [markdown]
# Cell 4: Verify Cell Type

# %%
print("="*60)
print("CELL TYPE VERIFICATION")
print("="*60)

sample = list(gse.gsms.values())[0]
print("Sample characteristics:")
for char in sample.metadata.get('characteristics_ch1', []):
    print(f"  {char}")

print("\n✅ Confirmed: THP-1 macrophages")
# Out:
# ============================================================
# CELL TYPE VERIFICATION
# ============================================================
# Sample characteristics:
#   cell line: THP-1
#   differentiation status: macrophages
#   exposure: 100 ug of CNM in 1ml of RPMI medium
#   exposure method: differentiated THP-1 cells in culture
#   time: 24
#
# ✅ Confirmed: THP-1 macrophages

# %% [markdown]
# Cell 5: Extract Expression Data

# %%
print("="*60)
print("EXTRACTING EXPRESSION DATA")
print("="*60)

# Get expression data from each sample
expr_dfs = []
for gsm_name, gsm in gse.gsms.items():
    sample_expr = gsm.table[["ID_REF", "VALUE"]].copy()
    sample_expr.columns = ["ProbeID", gsm_name]
    expr_dfs.append(sample_expr)

# Merge all samples
expr_matrix = expr_dfs[0]
for df in expr_dfs[1:]:
    expr_matrix = expr_matrix.merge(df, on="ProbeID", how="outer")

print(f"✅ Expression matrix: {expr_matrix.shape}")
print(f"   Probes: {expr_matrix.shape[0]}")
print(f"   Samples: {expr_matrix.shape[1] - 1}")
# Out:
# ============================================================
# EXTRACTING EXPRESSION DATA
# ============================================================
# ✅ Expression matrix: (62976, 73)
#    Probes: 62976
#    Samples: 72

# %% [markdown]
# Cell 6: Map Probes to Gene Symbols

# %%
print("="*60)
print("MAPPING PROBES TO GENE SYMBOLS")
print("="*60)

# Extract gene mapping
gpl_table = gpl.table
gpl_genes = gpl_table[~gpl_table["GENE_SYMBOL"].isna()].copy()
gene_map = gpl_genes[["ID", "GENE_SYMBOL"]].copy()
gene_map.columns = ["ProbeID", "GeneSymbol"]
gene_map = gene_map[gene_map["GeneSymbol"].str.strip() != ""]

print(f"✅ Gene mapping: {len(gene_map)} probes with symbols")

# Merge and collapse to genes
expr_reset = expr_matrix.rename(columns={"ProbeID": "ID"})
merged = expr_reset.merge(gene_map.rename(columns={"ProbeID": "ID"}), on="ID", how="inner")
merged = merged.dropna(subset=["GeneSymbol"])
expr_by_gene = merged.groupby("GeneSymbol").mean(numeric_only=True)

print(f"✅ Gene-level expression: {expr_by_gene.shape}")
print(f"   Genes: {expr_by_gene.shape[0]}")
print(f"   Samples: {expr_by_gene.shape[1]}")
# Out:
# ============================================================
# MAPPING PROBES TO GENE SYMBOLS
# ============================================================
# ✅ Gene mapping: 38422 probes with symbols
# ✅ Gene-level expression: (22682, 73)
#    Genes: 22682
#    Samples: 73

# %% [markdown]
# Cell 7: Comparison 1 - 2D Graphene vs Control

# %%
print("="*60)
print("COMPARISON 1: 2D GRAPHENE (SES) vs CONTROL")
print("="*60)

# Extract samples
negCont_24h = meta_df.query("treatment == 'negCont' and timepoint == '24h'").index.tolist()
SES_24h = meta_df.query("treatment == 'SES' and timepoint == '24h'").index.tolist()

# Get sample names
negCont_samples = meta_df.loc[negCont_24h, 'GSM'].tolist()
SES_samples = meta_df.loc[SES_24h, 'GSM'].tolist()

print(f"Control samples (n={len(negCont_samples)}): {negCont_samples}")
print(f"SES/Graphene samples (n={len(SES_samples)}): {SES_samples}")

# Subset expression data
subset_ses = expr_by_gene[negCont_samples + SES_samples]

# Calculate t-statistics
grp_control_ses = subset_ses[negCont_samples]
grp_SES = subset_ses[SES_samples]

m_control_ses = grp_control_ses.mean(axis=1)
m_SES = grp_SES.mean(axis=1)

v_control_ses = grp_control_ses.var(axis=1)
v_SES = grp_SES.var(axis=1)

n_control_ses = grp_control_ses.shape[1]
n_SES = grp_SES.shape[1]

# Welch t-statistic (positive = UP in graphene)
tstat_ses = (m_SES - m_control_ses) / np.sqrt(
    v_SES/n_SES + v_control_ses/n_control_ses + 1e-12
)

# Create ranked list
rnk_ses = pd.DataFrame({
    "gene": subset_ses.index,
    "score": tstat_ses
}).dropna()

# Handle duplicates
rnk_ses = rnk_ses.loc[rnk_ses.groupby("gene")["score"].apply(lambda s: s.abs().idxmax())]
rnk_ses = rnk_ses.sort_values("score", ascending=False)

print(f"\n✅ 2D Graphene ranked list: {len(rnk_ses)} genes")
print(f"   Top upregulated: {rnk_ses.iloc[0]['gene']} (t={rnk_ses.iloc[0]['score']:.2f})")
print(f"   Top downregulated: {rnk_ses.iloc[-1]['gene']} (t={rnk_ses.iloc[-1]['score']:.2f})")

# Save
rnk_ses.to_csv("kinaret_2D_graphene_vs_control.rnk", sep="\t", header=False, index=False)
print("✅ Saved: kinaret_2D_graphene_vs_control.rnk")
# Out:
# ============================================================
# COMPARISON 1: 2D GRAPHENE (SES) vs CONTROL
# ============================================================
# Control samples (n=6): ['GSM2439566', 'GSM2439568', 'GSM2439588', 'GSM2439590', 'GSM2439598', 'GSM2439605']
# SES/Graphene samples (n=3): ['GSM2439561', 'GSM2439591', 'GSM2439600']
#
# ✅ 2D Graphene ranked list: 22682 genes
#    Top upregulated: HEPH (t=8.25)
#    Top downregulated: DNAJC3 (t=-7.63)
# ✅ Saved: kinaret_2D_graphene_vs_control.rnk

# %% [markdown]
# Cell 8: Comparison 2 - 3D Fullerene vs Control

# %%
print("="*60)
print("COMPARISON 2: 3D FULLERENE vs CONTROL")
print("="*60)

# Extract samples
Fullerene_24h = meta_df.query("treatment == 'Fullerene' and timepoint == '24h'").index.tolist()
Fullerene_samples = meta_df.loc[Fullerene_24h, 'GSM'].tolist()

print(f"Control samples (n={len(negCont_samples)}): {negCont_samples}")
print(f"Fullerene samples (n={len(Fullerene_samples)}): {Fullerene_samples}")

# Subset expression data
subset_full = expr_by_gene[negCont_samples + Fullerene_samples]

# Calculate t-statistics
grp_control_full = subset_full[negCont_samples]
grp_Fullerene = subset_full[Fullerene_samples]

m_control_full = grp_control_full.mean(axis=1)
m_Fullerene = grp_Fullerene.mean(axis=1)

v_control_full = grp_control_full.var(axis=1)
v_Fullerene = grp_Fullerene.var(axis=1)

n_control_full = grp_control_full.shape[1]
n_Fullerene = grp_Fullerene.shape[1]

# Welch t-statistic (positive = UP in fullerene)
tstat_full = (m_Fullerene - m_control_full) / np.sqrt(
    v_Fullerene/n_Fullerene + v_control_full/n_control_full + 1e-12
)

# Create ranked list
rnk_full = pd.DataFrame({
    "gene": subset_full.index,
    "score": tstat_full
}).dropna()

# Handle duplicates
rnk_full = rnk_full.loc[rnk_full.groupby("gene")["score"].apply(lambda s: s.abs().idxmax())]
rnk_full = rnk_full.sort_values("score", ascending=False)

print(f"\n✅ 3D Fullerene ranked list: {len(rnk_full)} genes")
print(f"   Top upregulated: {rnk_full.iloc[0]['gene']} (t={rnk_full.iloc[0]['score']:.2f})")
print(f"   Top downregulated: {rnk_full.iloc[-1]['gene']} (t={rnk_full.iloc[-1]['score']:.2f})")

# Save
rnk_full.to_csv("kinaret_3D_fullerene_vs_control.rnk", sep="\t", header=False, index=False)
print("✅ Saved: kinaret_3D_fullerene_vs_control.rnk")
# Out:
# ============================================================
# COMPARISON 2: 3D FULLERENE vs CONTROL
# ============================================================
# Control samples (n=6): ['GSM2439566', 'GSM2439568', 'GSM2439588', 'GSM2439590', 'GSM2439598', 'GSM2439605']
# Fullerene samples (n=3): ['GSM2439572', 'GSM2439578', 'GSM2439599']
#
# ✅ 3D Fullerene ranked list: 22682 genes
#    Top upregulated: NUPR1 (t=12.16)
#    Top downregulated: DAAM1 (t=-7.37)
# ✅ Saved: kinaret_3D_fullerene_vs_control.rnk

# %% [markdown]
# Cell 9: Run GSEA - 2D Graphene

# %%
print("="*60)
print("RUNNING GSEA: 2D GRAPHENE")
print("="*60)

gsea_2d = gp.prerank(
    rnk="kinaret_2D_graphene_vs_control.rnk",
    gene_sets="MSigDB_Hallmark_2020",
    outdir="gsea_kinaret_2D_graphene",
    min_size=15,
    max_size=500,
    permutation_num=1000,
    seed=42,
    threads=4,
    format="png",
    verbose=True
)

print("✅ GSEA complete for 2D Graphene")
# Out:
# 2025-11-12 19:38:23,825 [INFO] Parsing data files for GSEA.............................
# ============================================================
# RUNNING GSEA: 2D GRAPHENE
# ============================================================
# 2025-11-12 19:38:24,515 [INFO] Downloading and generating Enrichr library gene sets......
# 2025-11-12 19:38:25,702 [INFO] 0000 gene_sets have been filtered out when max_size=500 and min_size=15
# 2025-11-12 19:38:25,705 [INFO] 0050 gene_sets used for further statistical testing.....
# 2025-11-12 19:38:25,707 [INFO] Start to run GSEA...Might take a while..................
# 2025-11-12 19:38:45,611 [INFO] Congratulations. GSEApy runs successfully................
# ✅ GSEA complete for 2D Graphene

# %%
gsea_2d.res2d
# Out:
#        Name                               Term        ES       NES NOM p-val  \
# 0   prerank                        E2F Targets -0.560856 -2.809363       0.0
# 1   prerank                    G2-M Checkpoint -0.458448 -2.329464       0.0
# 2   prerank              Fatty Acid Metabolism -0.379959 -1.869459       0.0
# 3   prerank                     Myc Targets V1 -0.343947 -1.744441       0.0
# 4   prerank                       Adipogenesis -0.343945 -1.725389       0.0
# 5   prerank          Unfolded Protein Response -0.330994 -1.546914  0.005291
# 6   prerank          Interferon Alpha Response  0.326399  1.539241  0.002247
# 7   prerank      TNF-alpha Signaling via NF-kB -0.301416 -1.526833   0.00639
# 8   prerank                   mTORC1 Signaling -0.304175 -1.523374  0.001689
# 9   prerank                  Androgen Response -0.334922 -1.521609  0.013378
# 10  prerank                          Apoptosis -0.311305 -1.514113  0.004983
# 11  prerank          Oxidative Phosphorylation -0.286615 -1.433143  0.014851
# 12  prerank                     UV Response Dn -0.295324 -1.395352  0.028476
# 13  prerank                  Protein Secretion -0.304149 -1.390759  0.049069
# 14  prerank               Bile Acid Metabolism -0.288651 -1.333812  0.038062
# 15  prerank         Wnt-beta Catenin Signaling -0.338284 -1.319166  0.124324
# 16  prerank                         Myogenesis  0.242687  1.287213    0.0399
# 17  prerank                            Hypoxia -0.247937 -1.244795  0.088388
# 18  prerank                    Notch Signaling  0.334651  1.218483  0.202929
# 19  prerank             Estrogen Response Late -0.240686 -1.215843  0.096405
# 20  prerank                        Coagulation  0.232405  1.176564  0.136253
# 21  prerank                     UV Response Up -0.239152  -1.17045   0.16343
# 22  prerank                    Spermatogenesis -0.245708 -1.166355  0.186757
# 23  prerank           IL-6/JAK/STAT3 Signaling  0.250216   1.15286  0.181586
# 24  prerank                    Mitotic Spindle -0.227342 -1.142284   0.20598
# 25  prerank            Estrogen Response Early -0.228497 -1.142246  0.205342
# 26  prerank                Allograft Rejection -0.227359 -1.133372  0.187697
# 27  prerank                        Pperoxisome -0.248876 -1.130751  0.226619
# 28  prerank                  KRAS Signaling Dn -0.225101  -1.11845  0.249589
# 29  prerank                 TGF-beta Signaling -0.278657 -1.106611  0.267951
# 30  prerank                         Glycolysis -0.211725 -1.069009    0.2976
# 31  prerank                    heme Metabolism -0.209749  -1.06227  0.325696
# 32  prerank                    Apical Junction   0.20094  1.059828  0.324455
# 33  prerank                         DNA Repair -0.219724 -1.054891  0.342373
# 34  prerank          Interferon Gamma Response  0.199377  1.048899  0.337349
# 35  prerank                 Hedgehog Signaling -0.284232 -1.032044  0.412098
# 36  prerank    Reactive Oxygen Species Pathway -0.263001 -1.013116  0.417132
# 37  prerank                     Apical Surface  -0.25912 -0.996755  0.441652
# 38  prerank                         Complement  0.188767  0.992011  0.469543
# 39  prerank            Cholesterol Homeostasis -0.230272 -0.989353  0.466192
# 40  prerank                       Angiogenesis  0.249037  0.965612  0.508696
# 41  prerank  Epithelial Mesenchymal Transition -0.185419 -0.947011  0.595238
# 42  prerank                  KRAS Signaling Up -0.182167 -0.916109  0.667717
# 43  prerank              Xenobiotic Metabolism  -0.17931 -0.911005  0.691318
# 44  prerank               IL-2/STAT5 Signaling -0.177821 -0.906269  0.699482
# 45  prerank              Inflammatory Response -0.178274 -0.897876   0.72082
# 46  prerank           PI3K/AKT/mTOR  Signaling -0.195291 -0.889243  0.696707
# 47  prerank                Pancreas Beta Cells  0.209099  0.827507  0.776549
# 48  prerank                        p53 Pathway -0.150044 -0.754593  0.972039
# 49  prerank                     Myc Targets V2 -0.180139 -0.734519  0.894643
#
#    FDR q-val FWER p-val    Tag %  Gene %  \
# 0        0.0        0.0  102/185  25.21%
# 1        0.0        0.0   77/182  20.37%
# 2   0.004065      0.009   58/153  24.50%
# 3   0.010162       0.03   81/187  30.52%
# 4   0.011381      0.042   77/186  24.50%
# 5   0.052163      0.207   49/106  30.39%
# 6   0.070811      0.127    35/92  25.26%
# 7    0.05284      0.239   57/197  25.21%
# 8   0.047421      0.244   53/191  20.51%
# 9   0.042904      0.248    36/96  24.91%
# 10  0.042001      0.264   30/158  11.35%
# 11  0.078336      0.466   63/180  24.60%
# 12   0.09868      0.561   66/135  35.78%
# 13  0.094633      0.577    33/95  27.41%
# 14  0.145262      0.748   36/112  23.26%
# 15  0.153733       0.79    10/42  11.93%
# 16  0.320848      0.734   49/198  16.49%
# 17  0.254801      0.928   48/190  19.49%
# 18  0.363823      0.883     9/32  12.02%
# 19  0.296718      0.966   46/196  19.55%
# 20  0.371636      0.947   42/136  22.63%
# 21  0.378387      0.987   22/150  11.26%
# 22  0.369453      0.987   35/130  19.44%
# 23  0.352493      0.963    26/87  26.12%
# 24  0.412356      0.994   32/194   9.31%
# 25   0.39272      0.994   40/192  14.95%
# 26  0.395193      0.994   52/195  22.50%
# 27  0.385138      0.995   32/100  23.26%
# 28  0.396414      0.996   39/186  17.40%
# 29  0.408034      0.998    18/54  22.04%
# 30  0.488537        1.0   56/195  25.52%
# 31  0.486802        1.0   53/190  24.31%
# 32  0.543537      0.999   59/194  23.34%
# 33  0.489207        1.0   38/138  21.04%
# 34  0.494911      0.999   30/194  11.77%
# 35   0.52971        1.0     6/35  10.46%
# 36  0.563809        1.0    16/45  22.29%
# 37  0.590944        1.0    12/43  21.54%
# 38  0.592433      0.999   52/194  21.03%
# 39  0.593986        1.0    20/72  19.02%
# 40  0.596767        1.0     7/36  10.15%
# 41  0.692998        1.0   27/195  10.11%
# 42   0.75634        1.0   49/193  24.94%
# 43  0.748433        1.0   59/196  25.28%
# 44  0.740327        1.0   48/190  24.09%
# 45  0.741117        1.0   29/197  15.11%
# 46  0.742757        1.0   28/103  22.07%
# 47  0.854813        1.0    19/40  34.71%
# 48  0.960399        1.0   19/190  10.03%
# 49  0.952715        1.0     8/58  12.76%
#
#                                            Lead_genes
# 0   NUP107;CCNE1;BRCA2;MTHFD2;DUT;PPM1D;MCM6;CDCA3...
# 1   SMC2;BRCA2;MCM6;CENPA;MAD2L1;TRAIP;INCENP;RAD2...
# 2   BLVRA;AADAT;RAP1GDS1;ELOVL5;SUCLG1;BCKDHB;G0S2...
# 3   YWHAQ;DUT;MCM6;CCT4;MAD2L1;USP1;PSMD14;ODC1;HD...
# 4   DNAJC15;GBE1;DLAT;SUCLG1;ANGPT1;HADH;RNF11;NKI...
# 5   DNAJC3;CEBPG;MTHFD2;DCP2;NFYB;CKS1B;NOLC1;IMP3...
# 6   EIF2AK2;IFI30;IFI35;IFITM3;B2M;PARP14;IRF7;IFI...
# 7   BIRC2;G0S2;ZBTB10;NR4A3;SNN;B4GALT5;KLF2;BTG3;...
# 8   EGLN3;GBE1;SORD;MTHFD2;ELOVL5;CYB5B;TRIB3;PHGD...
# 9   SORD;ELOVL5;ZBTB10;ITGAV;GNAI3;BMPR1B;FADS1;VA...
# 10  DNAJC3;BGN;CTNNB1;PMAIP1;BTG3;NEDD9;IL18;PRF1;...
# 11  DLAT;SUCLG1;BDH2;PHYH;COX7C;NDUFB8;ATP6V1C1;AC...
# 12  BCKDHB;SCHIP1;FBLN5;NR1D2;DAB2;CDKN1B;PLCB4;CO...
# 13  RAB5A;TOM1L1;SGMS1;COPB2;SSPN;TPD52;SOD1;AP2M1...
# 14  OPTN;PHYH;TTR;CYP8B1;AR;PEX11A;FADS1;ACSL5;ABC...
# 15  CTNNB1;HDAC2;SKP2;TCF7;FRAT1;AXIN2;GNAI1;FZD1;...
# 16  ITGB5;TAGLN;TSC2;ACTA1;ACHE;LSP1;AK1;CHRNA1;MY...
# 17  GBE1;BGN;CDKN1C;CP;EDN2;SELENBP1;FAM162A;CDKN1...
# 18  APH1A;WNT2;NOTCH1;PPARD;MAML2;JAG1;PSENEN;LFNG...
# 19  SORD;FGFR3;ELOVL5;SNX10;SOX3;MEST;BTG3;DHRS2;C...
# 20  HRG;APOC1;MST1;WDR1;USP11;SERPINE1;SERPING1;IT...
# 21  CCNE1;CEBPG;C4BPB;HSPA2;CYB5B;PLCL1;CDKN1C;BTG...
# 22  TOPBP1;HSPA2;SIRT1;NEK2;ARL4A;CCT6B;NCAPH;GSTM...
# 23  IL17RA;IL1R2;MYD88;TNFRSF21;TNFRSF1B;GRB2;LTBR...
# 24  BRCA2;INCENP;SMC4;ALMS1;NET1;NEK2;KIFAP3;KIF23...
# 25  ELOVL5;SOX3;PMAIP1;DHRS2;MSMB;SLC1A1;AR;MPPED2...
# 26  HLA-DRA;LY75;TAP2;NLRP3;CD3G;LTB;IL7;IRF4;IL18...
# 27  ELOVL5;ABCC5;MSH2;TTR;ACOX1;PEX11A;FADS1;ACSL5...
# 28  RIBC2;FGFR3;NTF3;EDN2;PDCD1;GP1BA;C5;SNN;BMPR1...
# 29  CDKN1C;CTNNB1;WWTR1;ID2;RAB31;APC;CDH1;SMURF1;...
# 30  EGLN3;CENPA;AGL;ANG;CHST12;CHST4;COPB2;FAM162A...
# 31  BLVRA;OPTN;MFHAS1;MBOAT2;VEZF1;XK;CLIC2;CAST;M...
# 32  GTF2F1;CLDN7;ACTA1;ACTN1;CD34;CLDN8;KRT31;RAC2...
# 33  DUT;RFC3;RFC5;RPA3;DDB2;POLD1;RFC4;ZWINT;RAD51...
# 34  ITGB7;HLA-A;EIF2AK2;MYD88;IFI30;SERPING1;OAS2;...
# 35                    GLI1;AMOT;DPYSL2;RTN1;SCG2;CDK6
# 36  PRDX6;GSR;SOD1;PFKP;GLRX2;CDKN2D;PRDX2;PRDX4;P...
# 37  AKAP7;GHRL;GSTM3;BRCA1;DCBLD2;SRPX;ATP8B1;CX3C...
# 38  LCK;GZMB;APOC1;SERPINE1;SERPING1;ITIH1;TIMP1;C...
# 39  CTNNB1;GPX8;TRIB3;HMGCS1;GNAI1;ECH1;MVK;ATF3;P...
# 40        PGLYRP1;COL3A1;TNFRSF21;TIMP1;STC1;LPL;JAG1
# 41  BGN;ITGAV;SFRP1;FBLN5;MEST;MMP1;DAB2;GADD45A;H...
# 42  IL10RA;G0S2;PTPRR;MTMR10;PTBP2;TMEM176A;GPRC5B...
# 43  CYP2E1;ELOVL5;SPINT2;XDH;ACOX1;KYNU;GSTT2;IGFB...
# 44  CCNE1;IL10RA;SYNGR2;CDKN1C;ITGAV;LTB;ODC1;ARL4...
# 45  SGMS2;IL10RA;NLRP3;FPR1;GP1BA;GNAI3;IL18;SEMA4...
# 46  TRIB3;PITX2;RALB;CDKN1B;NCK1;ACACA;PRKAA2;PTEN...
# 47  STXBP1;SST;PKLR;FOXA2;GCK;NEUROD1;IAPP;NEUROG3...
# 48  CDKN2AIP;PPM1D;DNTTIP2;ABCC5;TRIB3;DDB2;GADD45...
# 49        SORD;NOLC1;GNL3;CBX3;HSPD1;RCL1;HSPE1;DDX18

# %%
terms = gsea_2d.res2d['Term'].tolist()

# Plot the 10th pathway (index 9)
gsea_2d.plot(terms=terms[32])

# %% [markdown]
# Cell 10: Run GSEA - 3D Fullerene

# %%
print("="*60)
print("RUNNING GSEA: 3D FULLERENE")
print("="*60)

gsea_3d = gp.prerank(
    rnk="kinaret_3D_fullerene_vs_control.rnk",
    gene_sets="MSigDB_Hallmark_2020",
    outdir="gsea_kinaret_3D_fullerene",
    min_size=15,
    max_size=500,
    permutation_num=1000,
    seed=42,
    threads=4,
    format="png",
    verbose=True
)

print("✅ GSEA complete for 3D Fullerene")
# Out:
# 2025-11-12 19:39:04,395 [INFO] Parsing data files for GSEA.............................
# 2025-11-12 19:39:04,431 [INFO] Enrichr library gene sets already downloaded in: /root/.cache/gseapy, use local file
# 2025-11-12 19:39:04,445 [INFO] 0000 gene_sets have been filtered out when max_size=500 and min_size=15
# 2025-11-12 19:39:04,446 [INFO] 0050 gene_sets used for further statistical testing.....
# 2025-11-12 19:39:04,448 [INFO] Start to run GSEA...Might take a while..................
# ============================================================
# RUNNING GSEA: 3D FULLERENE
# ============================================================
# 2025-11-12 19:39:20,187 [INFO] Congratulations. GSEApy runs successfully................
# ✅ GSEA complete for 3D Fullerene

# %%
gsea_3d.res2d
# Out:
#        Name                               Term        ES       NES NOM p-val  \
# 0   prerank                        E2F Targets  0.416061  1.995478       0.0
# 1   prerank                    G2-M Checkpoint  0.352261  1.696896  0.001931
# 2   prerank                    Spermatogenesis  0.338784  1.545876   0.00409
# 3   prerank                  Protein Secretion -0.350637 -1.516058  0.001942
# 4   prerank          Interferon Alpha Response  0.349932  1.503206  0.012048
# 5   prerank                        Pperoxisome  0.325309  1.406291  0.028866
# 6   prerank                   mTORC1 Signaling  0.289066  1.402544  0.008147
# 7   prerank           IL-6/JAK/STAT3 Signaling -0.323769 -1.384281  0.033663
# 8   prerank          Oxidative Phosphorylation  0.288651  1.381016  0.012397
# 9   prerank    Reactive Oxygen Species Pathway   0.35482   1.32551  0.094538
# 10  prerank               Bile Acid Metabolism  0.288161  1.279993  0.073123
# 11  prerank            Estrogen Response Early  0.254656  1.228668  0.082828
# 12  prerank             Estrogen Response Late  0.251482   1.20024  0.105469
# 13  prerank                       Angiogenesis -0.332525 -1.199493  0.184061
# 14  prerank                        Coagulation -0.260184 -1.185114     0.128
# 15  prerank         Wnt-beta Catenin Signaling  0.318909   1.17193  0.208417
# 16  prerank                  KRAS Signaling Up  -0.24017 -1.152647  0.150476
# 17  prerank                 TGF-beta Signaling -0.289524 -1.144702  0.222222
# 18  prerank          Interferon Gamma Response  0.235563  1.140799  0.148536
# 19  prerank                Allograft Rejection  0.230459   1.12813  0.178218
# 20  prerank                 Hedgehog Signaling -0.315388 -1.107389  0.311475
# 21  prerank                    Mitotic Spindle  0.229267  1.099492  0.224033
# 22  prerank                    Apical Junction  0.229426  1.094702  0.229508
# 23  prerank                       Adipogenesis  0.225931  1.087609  0.254438
# 24  prerank                    heme Metabolism   0.22476  1.083258  0.251509
# 25  prerank                     Myc Targets V1  0.215861  1.040294  0.359918
# 26  prerank              Xenobiotic Metabolism  0.211827  1.031854   0.36714
# 27  prerank              Fatty Acid Metabolism  0.223474  1.028059  0.416667
# 28  prerank                        p53 Pathway  0.211011  1.022283  0.405882
# 29  prerank                         Myogenesis  0.205647  1.004351   0.43361
# 30  prerank              Inflammatory Response  0.200336  0.987987  0.484848
# 31  prerank                Pancreas Beta Cells -0.264212 -0.970928   0.48497
# 32  prerank           PI3K/AKT/mTOR  Signaling  0.220549  0.964851  0.553191
# 33  prerank                     Apical Surface  0.254452  0.952735  0.534274
# 34  prerank      TNF-alpha Signaling via NF-kB -0.195882 -0.947434  0.619608
# 35  prerank                         Glycolysis  0.194129   0.94264     0.594
# 36  prerank                         Complement -0.195058 -0.942265  0.623352
# 37  prerank               IL-2/STAT5 Signaling  0.190778  0.924034  0.668712
# 38  prerank                     UV Response Up  0.197558  0.917256  0.660494
# 39  prerank                     Myc Targets V2  0.230748  0.893695  0.665198
# 40  prerank                  KRAS Signaling Dn -0.183513 -0.889953  0.768612
# 41  prerank                     UV Response Dn  -0.18364  -0.84037  0.846465
# 42  prerank                          Apoptosis  0.177868  0.838315  0.856311
# 43  prerank            Cholesterol Homeostasis  0.201706  0.834429  0.776908
# 44  prerank                         DNA Repair  0.180815  0.829101  0.879668
# 45  prerank  Epithelial Mesenchymal Transition  0.164277  0.803181  0.946322
# 46  prerank                            Hypoxia -0.159076 -0.764956  0.982422
# 47  prerank          Unfolded Protein Response  0.168269  0.744454  0.951983
# 48  prerank                    Notch Signaling  0.206722  0.712359  0.880539
# 49  prerank                  Androgen Response -0.131481 -0.581498  0.998043
#
#    FDR q-val FWER p-val   Tag %  Gene %  \
# 0        0.0        0.0  59/185  15.62%
# 1   0.016706      0.023  58/182  21.53%
# 2   0.064888      0.125  43/130  20.68%
# 3   0.114358      0.188   37/95  27.31%
# 4     0.0799      0.197   35/92  27.94%
# 5   0.158347      0.414  26/100  16.52%
# 6   0.136072      0.423  52/191  22.21%
# 7   0.179032      0.461   32/87  26.16%
# 8   0.138009      0.481  80/180  32.71%
# 9   0.200839      0.654   18/45  24.95%
# 10  0.261813      0.778  31/112  18.92%
# 11  0.352867      0.869  39/192  14.28%
# 12  0.402933      0.927  64/196  25.88%
# 13  0.575307      0.938   15/36  26.14%
# 14  0.482969      0.954  44/136  25.52%
# 15  0.452766      0.957    9/42  14.33%
# 16  0.493184      0.985  59/193  26.29%
# 17   0.43421      0.987    9/54   8.52%
# 18  0.525775      0.987  58/194  25.62%
# 19  0.535952       0.99  42/195  18.59%
# 20  0.481224      0.999   12/35  24.91%
# 21   0.60598      0.996  67/194  27.77%
# 22  0.585812      0.996  54/194  22.20%
# 23  0.577416      0.996  55/186  24.73%
# 24  0.561317      0.998  63/190  27.75%
# 25   0.68691        1.0  58/187  25.41%
# 26   0.68605        1.0  69/196  28.94%
# 27  0.667908        1.0  44/153  25.79%
# 28  0.657292        1.0  49/190  26.45%
# 29  0.691813        1.0  54/198  23.63%
# 30  0.720915        1.0  16/197   6.23%
# 31  0.919237        1.0    5/40   6.97%
# 32  0.778312        1.0  18/103  13.95%
# 33  0.789724        1.0   21/43  31.31%
# 34  0.907896        1.0  66/197  28.61%
# 35  0.795502        1.0  48/195  25.37%
# 36  0.833927        1.0  45/194  22.83%
# 37  0.825719        1.0  29/190  13.87%
# 38  0.818336        1.0  46/150  28.35%
# 39  0.860595        1.0   13/58  18.53%
# 40  0.924505        1.0  50/186  24.66%
# 41  0.974127        1.0  25/135  16.88%
# 42  0.976794        1.0  41/158  24.38%
# 43  0.954668        1.0   15/72  22.23%
# 44  0.936568        1.0  42/138  27.43%
# 45  0.951108        1.0  46/195  22.83%
# 46       1.0        1.0  48/190  26.93%
# 47  0.985488        1.0  16/106  13.95%
# 48  0.975425        1.0   10/32  26.40%
# 49  0.997779        1.0    2/96   0.32%
#
#                                            Lead_genes
# 0   NASP;KIF22;AURKB;MYBL2;KIF2C;PRDX4;ASF1B;PTTG1...
# 1   NASP;KIF22;AURKB;MYBL2;E2F1;KIF2C;PTTG1;NDC80;...
# 2   ZNRF4;KIF2C;TEKT2;HOXB1;TTK;CAMK4;TALDO1;ACRBP...
# 3   STX12;CLTC;MON2;EGFR;VAMP3;STX16;SEC22B;GOSR2;...
# 4   TMEM140;TRIM25;RTP4;IFITM1;IRF1;PSMA3;TDRD7;PS...
# 5   MVP;ACOX1;ESR2;SLC27A2;ABCC8;CACNA1B;TOP2A;PRD...
# 6   NUPR1;FADS2;GBE1;DHFR;DDIT4;CFP;GGA2;MCM2;SLC1...
# 7   IL13RA1;IL7;DNTT;CBL;IFNGR2;IL1R2;PTPN1;STAT3;...
# 8   PDK4;HADHA;UQCRQ;POR;NDUFA1;COX15;MRPL11;NDUFA...
# 9   NQO1;PRDX4;FTL;HMOX2;PRDX1;NDUFS2;TXNRD2;NDUFB...
# 10  CYP27A1;FADS2;SLC27A2;OPTN;AMACR;PAOX;NR0B2;DI...
# 11  SLC27A2;BCL11B;LRIG1;FKBP5;CLDN7;SLC1A4;AMFR;B...
# 12  DNAJC1;SLC27A2;MDK;NAB2;FKBP5;SLC1A4;AMFR;BLVR...
# 13  PGLYRP1;THBD;TNFRSF21;LUM;VEGFA;VAV2;FGFR1;PTK...
# 14  F11;MBL2;CFB;MMP7;CFI;PROZ;THBD;PLEK;FN1;F9;TH...
# 15  CTNNB1;DLL1;WNT1;TP53;FRAT1;SKP2;GNAI1;WNT6;MAML1
# 16  NIN;HOXD11;PTBP2;SERPINA3;RETN;PPBP;CFB;CBL;CP...
# 17  HIPK2;IFNGR2;CDK9;SMURF1;THBS1;TGFB1;SMURF2;AC...
# 18  MVP;TRIM25;TNFSF10;RTP4;ZBP1;FPR1;PSMA2;SERPIN...
# 19  CD8A;F2;SRGN;IGSF6;HLA-DRA;CD3E;CFP;IL16;RPL39...
# 20  OPHN1;VEGFA;UNC5C;CELSR1;MYH9;PTCH1;L1CAM;CNTF...
# 21  KIF22;KIF2C;NDC80;TTK;CDC42EP4;ESPL1;NUSAP1;CC...
# 22  ITGA9;ICAM2;AKT3;CLDN18;ARHGEF6;CDH15;CADM3;MD...
# 23  ACOX1;GBE1;UQCRQ;ADIG;POR;SLC19A1;GHITM;TKT;TA...
# 24  CA1;ABCG2;P4HA2;OPTN;UROD;ACSL6;TRAK2;ALDH1L1;...
# 25  PSMA2;PRDX4;NOP56;MRPL23;MCM2;NHP2;NDUFAB1;EEF...
# 26  CYP27A1;PDK4;ACOX1;NQO1;FETUB;POR;CYP2S1;DDAH2...
# 27  NCAPH2;ACOX1;CYP4A22;UROD;PSME1;PDHB;FMO1;NTHL...
# 28  NUPR1;TNFSF9;GM2A;DDIT4;HINT1;PLK2;STEAP3;RXRA...
# 29  NCAM1;NQO1;MYOM1;FXYD1;APOD;COX6A2;BIN1;ACTA1;...
# 30  TACR1;TNFSF10;RTP4;SLC28A2;TNFSF9;FPR1;GABBR1;...
# 31                        G6PC2;SLC2A2;INSM1;ISL1;GCG
# 32  FGF22;DUSP3;E2F1;CAMK4;MAPK8;PRKAA2;PRKCB;FASL...
# 33  RTN4RL1;SCUBE1;PCSK9;HSPB1;RHCG;ADIPOR2;GSTM3;...
# 34  BIRC2;IFNGR2;KYNU;SERPINB8;PLEK;TNIP2;PTX3;PLA...
# 35  LHX9;NASP;P4HA2;GALK1;DDIT4;ALG1;STMN1;TALDO1;...
# 36  MMP13;S100A12;GMFB;USP14;PPP2CB;CFB;PCLO;KYNU;...
# 37  TNFSF10;TNFRSF18;RHOB;AMACR;LRIG1;ST3GAL4;IL10...
# 38  RHOB;UROD;PSMC3;IRF1;MRPL23;TYRO3;TACR3;FMO1;O...
# 39  NOP56;SLC19A1;MAP3K6;PLK4;MCM5;NPM1;RRP12;PLK1...
# 40  BMPR1B;NR6A1;TAS2R4;GPR3;KCNE2;EPHA5;TGM1;SERP...
# 41  GRK5;MAGI2;DLC1;PIAS3;DLG1;IRS1;TGFBR2;TGFBR3;...
# 42  TNFSF10;F2;BMF;RHOB;CTNNB1;MCL1;IRF1;RNASEL;TO...
# 43  FADS2;CTNNB1;MAL2;GPX8;CYP51A1;TRIB3;CHKA;TP53...
# 44  GUK1;POLA2;PCNA;RALA;TAF10;GTF3C5;DCTN4;ZWINT;...
# 45  ECM2;RHOB;MGP;COL1A2;COMP;SPARC;LOXL2;LAMA3;MF...
# 46  BGN;EGFR;HS3ST1;CA12;GPC4;DCN;IGFBP1;PLAUR;PPF...
# 47  DDIT4;NOP56;BAG3;SLC1A4;NHP2;CKS1B;SLC7A5;WFS1...
# 48  DLL1;APH1A;FZD7;LFNG;ARRB1;WNT2;SKP1;PSENEN;DT...
# 49                                         MAK;BMPR1B

# %%
terms = gsea_3d.res2d['Term'].tolist()

# Plot the 10th pathway (index 9)
gsea_3d.plot(terms=terms[32])

# %% [markdown]
# Cell 11: Extract and Compare Results

# %%
print("="*60)
print("EXTRACTING AND COMPARING RESULTS")
print("="*60)

# Extract results
res_2d = gsea_2d.res2d[['Term', 'NES', 'NOM p-val', 'FDR q-val']].copy()
res_2d['Material'] = '2D_Graphene'
res_2d['Dimensionality'] = '2D'

res_3d = gsea_3d.res2d[['Term', 'NES', 'NOM p-val', 'FDR q-val']].copy()
res_3d['Material'] = '3D_Fullerene'
res_3d['Dimensionality'] = '3D'

# Filter for significant pathways (FDR < 0.25)
sig_2d = res_2d[res_2d['FDR q-val'] < 0.25].copy()
sig_3d = res_3d[res_3d['FDR q-val'] < 0.25].copy()

print(f"\nSignificant pathways (FDR < 0.25):")
print(f"  2D Graphene:  {len(sig_2d)}")
print(f"  3D Fullerene: {len(sig_3d)}")

# Find overlapping pathways
sig_terms_2d = set(sig_2d['Term'])
sig_terms_3d = set(sig_3d['Term'])

overlap = sig_terms_2d & sig_terms_3d
only_2d = sig_terms_2d - sig_terms_3d
only_3d = sig_terms_3d - sig_terms_2d

print(f"\nPathway overlap analysis:")
print(f"  Shared (both 2D and 3D):  {len(overlap)}")
print(f"  2D-specific (graphene):   {len(only_2d)}")
print(f"  3D-specific (fullerene):  {len(only_3d)}")

# Calculate overlap percentage
total_unique = len(sig_terms_2d | sig_terms_3d)
overlap_pct = (len(overlap) / total_unique * 100) if total_unique > 0 else 0
print(f"  Overlap percentage:       {overlap_pct:.1f}%")
# Out:
# ============================================================
# EXTRACTING AND COMPARING RESULTS
# ============================================================
#
# Significant pathways (FDR < 0.25):
#   2D Graphene:  16
#   3D Fullerene: 10
#
# Pathway overlap analysis:
#   Shared (both 2D and 3D):  6
#   2D-specific (graphene):   10
#   3D-specific (fullerene):  4
#   Overlap percentage:       30.0%

# %% [markdown]
# Cell 12: Analyze Shared Pathways

# %%
print("="*60)
print("SHARED BIOLOGICAL RESPONSES (2D and 3D)")
print("="*60)

if len(overlap) > 0:
    shared_analysis = []

    for term in overlap:
        nes_2d = sig_2d[sig_2d['Term'] == term]['NES'].values[0]
        nes_3d = sig_3d[sig_3d['Term'] == term]['NES'].values[0]

        fdr_2d = sig_2d[sig_2d['Term'] == term]['FDR q-val'].values[0]
        fdr_3d = sig_3d[sig_3d['Term'] == term]['FDR q-val'].values[0]

        # Check direction
        same_direction = (nes_2d > 0 and nes_3d > 0) or (nes_2d < 0 and nes_3d < 0)

        shared_analysis.append({
            'Term': term,
            'NES_2D': nes_2d,
            'NES_3D': nes_3d,
            'FDR_2D': fdr_2d,
            'FDR_3D': fdr_3d,
            'Same_Direction': same_direction,
            'Avg_NES': (abs(nes_2d) + abs(nes_3d)) / 2
        })

    shared_df = pd.DataFrame(shared_analysis)
    shared_df = shared_df.sort_values('Avg_NES', ascending=False)

    print(f"\nTop 10 shared pathways (by average |NES|):")
    print("-"*80)
    for idx, row in shared_df.head(10).iterrows():
        direction = "✅ SAME" if row['Same_Direction'] else "⚠️ OPPOSITE"
        print(f"{row['Term'][:50]:50s}")
        print(f"  2D: NES={row['NES_2D']:6.2f} (FDR={row['FDR_2D']:.4f})  |  " +
              f"3D: NES={row['NES_3D']:6.2f} (FDR={row['FDR_3D']:.4f})  [{direction}]")

    # Calculate NES correlation
    corr = np.corrcoef(shared_df['NES_2D'], shared_df['NES_3D'])[0, 1]
    print(f"\n📊 NES Correlation for shared pathways: r = {corr:.3f}")

    if corr > 0.7:
        print("   ✅ Strong positive correlation - similar mechanisms")
    elif corr > 0.4:
        print("   ⚠️ Moderate correlation - partially similar mechanisms")
    else:
        print("   ❌ Weak correlation - different mechanisms")

    # Save shared pathways
    shared_df.to_csv("kinaret_2D_vs_3D_shared_pathways.csv", index=False)
    print("\n✅ Saved: kinaret_2D_vs_3D_shared_pathways.csv")
else:
    print("⚠️ No shared pathways found (FDR < 0.25)")
    shared_df = None
    corr = None
# Out:
# ============================================================
# SHARED BIOLOGICAL RESPONSES (2D and 3D)
# ============================================================
#
# Top 10 shared pathways (by average |NES|):
# --------------------------------------------------------------------------------
# E2F Targets
#   2D: NES= -2.81 (FDR=0.0000)  |  3D: NES=  2.00 (FDR=0.0000)  [⚠️ OPPOSITE]
# G2-M Checkpoint
#   2D: NES= -2.33 (FDR=0.0000)  |  3D: NES=  1.70 (FDR=0.0167)  [⚠️ OPPOSITE]
# Interferon Alpha Response
#   2D: NES=  1.54 (FDR=0.0708)  |  3D: NES=  1.50 (FDR=0.0799)  [✅ SAME]
# mTORC1 Signaling
#   2D: NES= -1.52 (FDR=0.0474)  |  3D: NES=  1.40 (FDR=0.1361)  [⚠️ OPPOSITE]
# Protein Secretion
#   2D: NES= -1.39 (FDR=0.0946)  |  3D: NES= -1.52 (FDR=0.1144)  [✅ SAME]
# Oxidative Phosphorylation
#   2D: NES= -1.43 (FDR=0.0783)  |  3D: NES=  1.38 (FDR=0.1380)  [⚠️ OPPOSITE]
#
# 📊 NES Correlation for shared pathways: r = -0.071
#    ❌ Weak correlation - different mechanisms
#
# ✅ Saved: kinaret_2D_vs_3D_shared_pathways.csv

# %% [markdown]
# Cell 13: Display Material-Specific Pathways

# %%
print("="*60)
print("MATERIAL-SPECIFIC RESPONSES")
print("="*60)

if len(only_2d) > 0:
    print(f"\n2D-SPECIFIC PATHWAYS (Graphene only, n={len(only_2d)}):")
    print("-"*60)
    for term in list(only_2d)[:10]:
        nes = sig_2d[sig_2d['Term'] == term]['NES'].values[0]
        fdr = sig_2d[sig_2d['Term'] == term]['FDR q-val'].values[0]
        direction = "↑" if nes > 0 else "↓"
        print(f"  {direction} {term[:55]:55s}  NES={nes:6.2f}  FDR={fdr:.4f}")

if len(only_3d) > 0:
    print(f"\n3D-SPECIFIC PATHWAYS (Fullerene only, n={len(only_3d)}):")
    print("-"*60)
    for term in list(only_3d)[:10]:
        nes = sig_3d[sig_3d['Term'] == term]['NES'].values[0]
        fdr = sig_3d[sig_3d['Term'] == term]['FDR q-val'].values[0]
        direction = "↑" if nes > 0 else "↓"
        print(f"  {direction} {term[:55]:55s}  NES={nes:6.2f}  FDR={fdr:.4f}")
# Out:
# ============================================================
# MATERIAL-SPECIFIC RESPONSES
# ============================================================
#
# 2D-SPECIFIC PATHWAYS (Graphene only, n=10):
# ------------------------------------------------------------
#   ↓ Wnt-beta Catenin Signaling                               NES= -1.32  FDR=0.1537
#   ↓ Bile Acid Metabolism                                     NES= -1.33  FDR=0.1453
#   ↓ Myc Targets V1                                           NES= -1.74  FDR=0.0102
#   ↓ TNF-alpha Signaling via NF-kB                            NES= -1.53  FDR=0.0528
#   ↓ Androgen Response                                        NES= -1.52  FDR=0.0429
#   ↓ Apoptosis                                                NES= -1.51  FDR=0.0420
#   ↓ UV Response Dn                                           NES= -1.40  FDR=0.0987
#   ↓ Adipogenesis                                             NES= -1.73  FDR=0.0114
#   ↓ Fatty Acid Metabolism                                    NES= -1.87  FDR=0.0041
#   ↓ Unfolded Protein Response                                NES= -1.55  FDR=0.0522
#
# 3D-SPECIFIC PATHWAYS (Fullerene only, n=4):
# ------------------------------------------------------------
#   ↓ IL-6/JAK/STAT3 Signaling                                 NES= -1.38  FDR=0.1790
#   ↑ Spermatogenesis                                          NES=  1.55  FDR=0.0649
#   ↑ Pperoxisome                                              NES=  1.41  FDR=0.1583
#   ↑ Reactive Oxygen Species Pathway                          NES=  1.33  FDR=0.2008

# %% [markdown]
# Cell 14: Visualization - NES Correlation Scatter Plot

# %%
if len(overlap) > 0 and shared_df is not None:
    fig, ax = plt.subplots(figsize=(10, 10))

    ax.scatter(shared_df['NES_2D'], shared_df['NES_3D'],
               s=100, alpha=0.6, edgecolors='black', linewidth=1.5)

    # Add diagonal line
    lim = max(abs(shared_df['NES_2D'].max()), abs(shared_df['NES_3D'].max()),
              abs(shared_df['NES_2D'].min()), abs(shared_df['NES_3D'].min()))
    ax.plot([-lim, lim], [-lim, lim], 'r--', alpha=0.5, linewidth=2, label='Perfect correlation')

    # Add labels for top pathways
    for idx, row in shared_df.head(8).iterrows():
        ax.annotate(row['Term'][:30],
                   (row['NES_2D'], row['NES_3D']),
                   fontsize=8, alpha=0.7,
                   xytext=(5, 5), textcoords='offset points')

    ax.set_xlabel('NES: 2D Graphene (SES)', fontsize=14, fontweight='bold')
    ax.set_ylabel('NES: 3D Fullerene', fontsize=14, fontweight='bold')
    ax.set_title(f'2D vs 3D Pathway Enrichment Correlation\n' +
                 f'THP-1 Cells (n={len(overlap)} shared pathways, r={corr:.3f})',
                 fontsize=16, fontweight='bold', pad=20)
    ax.axhline(0, color='gray', linestyle='--', alpha=0.3, linewidth=1)
    ax.axvline(0, color='gray', linestyle='--', alpha=0.3, linewidth=1)
    ax.grid(True, alpha=0.3)
    ax.legend(fontsize=12)

    plt.tight_layout()
    plt.savefig('kinaret_2D_vs_3D_NES_correlation.png', dpi=300, bbox_inches='tight')
    print("✅ Saved: kinaret_2D_vs_3D_NES_correlation.png")
    plt.show()
# Out:
# ✅ Saved: kinaret_2D_vs_3D_NES_correlation.png

# %%
# Cell 15: Visualization - Heatmap

# Prepare heatmap data
all_sig_terms = sorted(list(sig_terms_2d | sig_terms_3d))

if len(all_sig_terms) > 0:
    heatmap_data = []
    for term in all_sig_terms:
        row = {'Term': term}

        if term in sig_2d['Term'].values:
            row['2D_Graphene'] = sig_2d[sig_2d['Term'] == term]['NES'].values[0]
        else:
            row['2D_Graphene'] = 0

        if term in sig_3d['Term'].values:
            row['3D_Fullerene'] = sig_3d[sig_3d['Term'] == term]['NES'].values[0]
        else:
            row['3D_Fullerene'] = 0

        heatmap_data.append(row)

    heatmap_df = pd.DataFrame(heatmap_data).set_index('Term')

    # Sort by average absolute NES
    heatmap_df['avg_abs_nes'] = (heatmap_df['2D_Graphene'].abs() +
                                  heatmap_df['3D_Fullerene'].abs()) / 2
    heatmap_df = heatmap_df.sort_values('avg_abs_nes', ascending=False)
    heatmap_df = heatmap_df.drop('avg_abs_nes', axis=1)

    # Plot heatmap
    fig, ax = plt.subplots(figsize=(8, max(10, len(all_sig_terms) * 0.35)))
    sns.heatmap(heatmap_df, cmap='RdBu_r', center=0, vmin=-3, vmax=3,
                annot=True, fmt='.2f',
                cbar_kws={'label': 'Normalized Enrichment Score (NES)'},
                linewidths=0.5, ax=ax)
    ax.set_title('Pathway Enrichment: 2D Graphene vs 3D Fullerene\nTHP-1 Macrophages (24h)',
                 fontsize=14, fontweight='bold', pad=20)
    ax.set_xlabel('Material Type', fontsize=12, fontweight='bold')
    ax.set_ylabel('Hallmark Pathway', fontsize=12, fontweight='bold')
    plt.tight_layout()
    plt.savefig('kinaret_2D_vs_3D_heatmap.png', dpi=300, bbox_inches='tight')
    print("✅ Saved: kinaret_2D_vs_3D_heatmap.png")
    plt.show()
else:
    print("⚠️ No significant pathways found in either material")
# Out:
# ✅ Saved: kinaret_2D_vs_3D_heatmap.png

# %%
try:
    from matplotlib_venn import venn2

    fig, ax = plt.subplots(figsize=(10, 8))
    venn2([sig_terms_2d, sig_terms_3d],
          set_labels=('2D Graphene', '3D Fullerene'),
          set_colors=('#3498db', '#e74c3c'),
          alpha=0.7,
          ax=ax)
    ax.set_title(f'Overlap of Enriched Pathways (FDR < 0.25)\n' +
                 f'Shared: {len(overlap)}/{total_unique} ({overlap_pct:.1f}%)',
                 fontsize=14, fontweight='bold', pad=20)
    plt.tight_layout()
    plt.savefig('kinaret_2D_vs_3D_venn.png', dpi=300, bbox_inches='tight')
    print("✅ Saved: kinaret_2D_vs_3D_venn.png")
    plt.show()
except ImportError:
    print("⚠️ matplotlib_venn not installed - skipping Venn diagram")
    print("   Install with: !pip install matplotlib-venn")
# Out:
# ✅ Saved: kinaret_2D_vs_3D_venn.png

# %%
# ============================================================
# VERIFICATION: Are negative NES scores real?
# ============================================================

print("="*60)
print("VERIFICATION CHECKS")
print("="*60)

# Check 1: Verify t-statistic direction
print("\n[CHECK 1] T-statistic sign verification")
print("-"*60)

# Look at top positive gene (should be UP in graphene)
top_up_gene = rnk_ses.iloc[0]['gene']
print(f"Top UPREGULATED gene: {top_up_gene}")
print(f"  t-statistic: {rnk_ses.iloc[0]['score']:.3f}")
print(f"  Control mean:  {grp_control_ses.loc[top_up_gene].mean():.3f}")
print(f"  Graphene mean: {grp_SES.loc[top_up_gene].mean():.3f}")
print(f"  Difference:    {grp_SES.loc[top_up_gene].mean() - grp_control_ses.loc[top_up_gene].mean():.3f}")
if rnk_ses.iloc[0]['score'] > 0:
    if grp_SES.loc[top_up_gene].mean() > grp_control_ses.loc[top_up_gene].mean():
        print("  ✅ CORRECT: Positive t-stat, graphene > control")
    else:
        print("  ❌ ERROR: Sign is backwards!")

# Look at bottom negative gene (should be DOWN in graphene)
top_down_gene = rnk_ses.iloc[-1]['gene']
print(f"\nTop DOWNREGULATED gene: {top_down_gene}")
print(f"  t-statistic: {rnk_ses.iloc[-1]['score']:.3f}")
print(f"  Control mean:  {grp_control_ses.loc[top_down_gene].mean():.3f}")
print(f"  Graphene mean: {grp_SES.loc[top_down_gene].mean():.3f}")
print(f"  Difference:    {grp_SES.loc[top_down_gene].mean() - grp_control_ses.loc[top_down_gene].mean():.3f}")
if rnk_ses.iloc[-1]['score'] < 0:
    if grp_SES.loc[top_down_gene].mean() < grp_control_ses.loc[top_down_gene].mean():
        print("  ✅ CORRECT: Negative t-stat, graphene < control")
    else:
        print("  ❌ ERROR: Sign is backwards!")

# Check 2: Overall expression comparison
print("\n[CHECK 2] Overall Expression Levels")
print("-"*60)
ctrl_overall = grp_control_ses.mean().mean()
ses_overall = grp_SES.mean().mean()
print(f"Control mean expression:  {ctrl_overall:.3f}")
print(f"Graphene mean expression: {ses_overall:.3f}")
print(f"Difference (Graphene - Control): {ses_overall - ctrl_overall:.3f}")

if ses_overall < ctrl_overall:
    print("  ⚠️ Graphene has LOWER overall expression than control")
    print("  This could indicate:")
    print("    - Global transcriptional suppression")
    print("    - Cell death/RNA degradation")
    print("    - Cells entering quiescence")

# Check 3: Sample quality (replicates should correlate)
print("\n[CHECK 3] Sample Correlation (Quality Check)")
print("-"*60)
from scipy.stats import pearsonr

# Control-Control correlations
ctrl_corrs = []
for i in range(len(negCont_samples)):
    for j in range(i+1, len(negCont_samples)):
        corr = pearsonr(grp_control_ses.iloc[:, i], grp_control_ses.iloc[:, j])[0]
        ctrl_corrs.append(corr)

# SES-SES correlations
ses_corrs = []
for i in range(len(SES_samples)):
    for j in range(i+1, len(SES_samples)):
        corr = pearsonr(grp_SES.iloc[:, i], grp_SES.iloc[:, j])[0]
        ses_corrs.append(corr)

print(f"Control-Control correlation: {np.mean(ctrl_corrs):.3f}")
print(f"Graphene-Graphene correlation: {np.mean(ses_corrs):.3f}")

if np.mean(ctrl_corrs) > 0.95 and np.mean(ses_corrs) > 0.95:
    print("  ✅ Replicates are highly correlated - good quality")
elif np.mean(ses_corrs) < 0.85:
    print("  ⚠️ Graphene replicates have low correlation - check data quality")

# Check 4: Are cells dying?
print("\n[CHECK 4] Cell Viability Markers")
print("-"*60)

# Apoptosis markers (if UP = cells dying)
apoptosis_genes = ['BAX', 'BCL2', 'CASP3', 'CASP8', 'CASP9', 'FAS', 'FASLG']
print("Apoptosis genes:")
apoptosis_changes = []
for gene in apoptosis_genes:
    if gene in subset_ses.index:
        ctrl_mean = grp_control_ses.loc[gene].mean()
        ses_mean = grp_SES.loc[gene].mean()
        fold_change = ses_mean - ctrl_mean
        apoptosis_changes.append(fold_change)
        direction = "↑" if fold_change > 0 else "↓"
        print(f"  {gene:8s}: {direction} {fold_change:+6.2f}")

if len(apoptosis_changes) > 0 and np.mean(apoptosis_changes) > 0.5:
    print("\n  ⚠️ Apoptosis markers are ELEVATED - cells may be dying")
elif len(apoptosis_changes) > 0 and np.mean(apoptosis_changes) < 0:
    print("\n  ✅ Apoptosis markers are NOT elevated - cells are viable")

# Housekeeping genes (should be stable)
housekeeping = ['ACTB', 'GAPDH', 'B2M', 'HPRT1', 'TBP']
print("\nHousekeeping genes (should be stable):")
for gene in housekeeping:
    if gene in subset_ses.index:
        ctrl_mean = grp_control_ses.loc[gene].mean()
        ses_mean = grp_SES.loc[gene].mean()
        fold_change = ses_mean - ctrl_mean
        print(f"  {gene:8s}: {fold_change:+6.2f}")

# Check 5: Compare to Fullerene (sanity check)
print("\n[CHECK 5] Compare to Fullerene (Sanity Check)")
print("-"*60)

# Count positive vs negative NES
graphene_up = (sig_2d['NES'] > 0).sum()
graphene_down = (sig_2d['NES'] < 0).sum()
fullerene_up = (sig_3d['NES'] > 0).sum()
fullerene_down = (sig_3d['NES'] < 0).sum()

print(f"2D Graphene significant pathways:")
print(f"  Upregulated (NES > 0):   {graphene_up}/{len(sig_2d)} ({graphene_up/len(sig_2d)*100:.0f}%)")
print(f"  Downregulated (NES < 0): {graphene_down}/{len(sig_2d)} ({graphene_down/len(sig_2d)*100:.0f}%)")

print(f"\n3D Fullerene significant pathways:")
print(f"  Upregulated (NES > 0):   {fullerene_up}/{len(sig_3d)} ({fullerene_up/len(sig_3d)*100:.0f}%)")
print(f"  Downregulated (NES < 0): {fullerene_down}/{len(sig_3d)} ({fullerene_down/len(sig_3d)*100:.0f}%)")

if graphene_down > graphene_up and fullerene_up > fullerene_down:
    print("\n  ✅ Pattern makes sense: Graphene suppressive, Fullerene activating")
    print("  This supports REAL biological difference, not technical artifact")

# Check 6: Look at E2F target genes directly
print("\n[CHECK 6] E2F Target Genes (Cell Cycle)")
print("-"*60)
e2f_genes = ['E2F1', 'CCNE1', 'CCNA2', 'CDC6', 'MCM2', 'PCNA']
print("Key E2F target genes:")
for gene in e2f_genes:
    if gene in subset_ses.index:
        ctrl_mean = grp_control_ses.loc[gene].mean()
        ses_mean = grp_SES.loc[gene].mean()
        fold_change = ses_mean - ctrl_mean
        direction = "↑" if fold_change > 0 else "↓"
        print(f"  {gene:8s}: {direction} {fold_change:+6.2f}")

print("\n" + "="*60)
print("VERIFICATION COMPLETE")
print("="*60)
# Out:
# ============================================================
# VERIFICATION CHECKS
# ============================================================
#
# [CHECK 1] T-statistic sign verification
# ------------------------------------------------------------
# Top UPREGULATED gene: HEPH
#   t-statistic: 8.246
#   Control mean:  7.120
#   Graphene mean: 7.370
#   Difference:    0.249
#   ✅ CORRECT: Positive t-stat, graphene > control
#
# Top DOWNREGULATED gene: DNAJC3
#   t-statistic: -7.631
#   Control mean:  10.571
#   Graphene mean: 9.911
#   Difference:    -0.660
#   ✅ CORRECT: Negative t-stat, graphene < control
#
# [CHECK 2] Overall Expression Levels
# ------------------------------------------------------------
# Control mean expression:  8.825
# Graphene mean expression: 8.839
# Difference (Graphene - Control): 0.014
#
# [CHECK 3] Sample Correlation (Quality Check)
# ------------------------------------------------------------
# Control-Control correlation: 0.982
# Graphene-Graphene correlation: 0.947
#
# [CHECK 4] Cell Viability Markers
# ------------------------------------------------------------
# Apoptosis genes:
#   BAX     : ↑  +0.24
#   BCL2    : ↓  -0.13
#   CASP3   : ↓  -0.12
#   CASP8   : ↓  -0.36
#   CASP9   : ↑  +0.65
#   FAS     : ↓  -0.19
#   FASLG   : ↑  +0.09
#
# Housekeeping genes (should be stable):
#   ACTB    :  +0.37
#   GAPDH   :  +0.38
#   B2M     :  +0.31
#   HPRT1   :  -0.45
#   TBP     :  -0.11
#
# [CHECK 5] Compare to Fullerene (Sanity Check)
# ------------------------------------------------------------
# 2D Graphene significant pathways:
#   Upregulated (NES > 0):   1/16 (6%)
#   Downregulated (NES < 0): 15/16 (94%)
#
# 3D Fullerene significant pathways:
#   Upregulated (NES > 0):   8/10 (80%)
#   Downregulated (NES < 0): 2/10 (20%)
#
#   ✅ Pattern makes sense: Graphene suppressive, Fullerene activating
#   This supports REAL biological difference, not technical artifact
#
# [CHECK 6] E2F Target Genes (Cell Cycle)
# ------------------------------------------------------------
# Key E2F target genes:
#   E2F1    : ↑  +0.11
#   CCNE1   : ↓  -0.81
#   CCNA2   : ↓  -0.76
#   CDC6    : ↓  -0.17
#   MCM2    : ↓  -0.14
#   PCNA    : ↓  -0.47
#
# ============================================================
# VERIFICATION COMPLETE
# ============================================================
